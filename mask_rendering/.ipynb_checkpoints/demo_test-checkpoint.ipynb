# %% [markdown]
# ## Test

# %% [markdown]
# ##### test 전에 아래 github 주소에서 모델과 라이브러리를 다운로드 받는다.
#  - https://github.com/cleardusk/3DDFA_V2
#
# ##### 3DDFA_V2 폴더 안에 "demo_modi.py"와 demo_test.ipynb를 복붙한다.

# %%
import demo_modi

# input image의 path를 입력, output 원본 이미지와 making된 이미지를 결합한 이미지 바이너리
res = demo_modi.mask3d_render(path_str = 'examples/inputs/emma.jpg')
# Out:
# examples/inputs/emma.jpg
# Detect 3 faces
# [[1699.8129, 278.49893, 2057.769, 762.4346, 0.9999492], [2999.3958, 304.8674, 3428.6719, 900.96783, 0.999895], [317.27078, 399.83633, 792.7346, 1048.3191, 0.99988747]]
# finished recon_vers
# Save visualization result to result02.png
# finished render

# %%
# 두 가지 방법으로 처리된 이미지 확인
import cv2
import matplotlib.pyplot as plt
# 1. 파일로 저장
cv2.imwrite('result03.png', res)
# 2. 이미지 보여주기
plt.imshow(res[..., ::-1])
